# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('RAIN MEAN DATA.csv')

Y = []
i=1
while(i<=19):
  Y.append(i)
  if len(Y)%240==0:
    i+=1

# %%
z = np.array(list(range(1,4561)))
Y = np.array(Y)

# %%
x = np.array(data['Time'])

# %%
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111,projection='3d')
"""
i=4
ax.plot(Y[240*(i-1):(240*i)-1],,x[240*(i-1):(240*i)-1],c='r',label=str(i))
i=5
ax.plot(Y[240*(i-1):(240*i)-1],x[240*(i-1):(240*i)-1],c='r',label=str(i))
"""
for i in range(1,20):
    plt.plot(z[240*(i-1):(240*i)-1],Y[240*(i-1):(240*i)-1]/2, x[240*(i-1):(240*i)-1],   c='r',label=str(i))
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5c503b3669d4> in <module>
#      13 """
#      14 for i in range(1,20):
# ---> 15     plt.plot(z[240*(i-1):(240*i)-1],Y[240*(i-1):(240*i)-1]/2, x[240*(i-1):(240*i)-1],   c='r',label=str(i))
#      16 ax.set_xlabel('x axis')
#      17 ax.set_ylabel('y axis')
#
# NameError: name 'z' is not defined

# %%
ax.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-ece30bd5e827> in <module>
# ----> 1 ax.show()
#
# AttributeError: 'Axes3DSubplot' object has no attribute 'show'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data1 = pd.read_csv('/content/drive/My Drive/TOTAL MEAN.csv')
data2 = pd.read_csv('/content/drive/My Drive/MAY5.csv')

# %%
y1 = np.array(data1.iloc[:,0])
y1 = y1[:239]

# %%
np.mean(y1) - np.mean(y2)

# %%
y2 = np.array(data2.iloc[:,0])
y2.shape

# %%
plt.plot(y1,color='b',label='1')
plt.plot(y2+24.62,color='r',label='2')

# %%
plt.plot(y1,color='b',label='1')
plt.plot(y2+24,color='r',label='2')
